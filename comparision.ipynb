# %%
t=[14,4,4,4,4,5,5,5,4,4,4,4,4,4,4]
g=[37,4,4,4,4,4,4,4,4,4,4,4,4,4,4]
c=[302,302,299,302,300,300,300,299,299,299,300,300,300,300,300]
x=[i for i in range(1,16)]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(x, t, label = "TPU", linestyle="--")
plt.plot(x, g, label = "GPU", linestyle="--")
#plt.plot(x, c, label = "CPU", linestyle="--")
plt.title("TPU vs GPU")
plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(x, t, label = "TPU", linestyle="--")
plt.plot(x, g, label = "GPU", linestyle="--")
plt.plot(x, c, label = "CPU", linestyle="--")
plt.title(" Batch training of TPU vs GPU vs CPU")
plt.legend()

# %%
x = ["CPU", "GPU", "TPU",]
y = [90, 91.71, 91.77]
plt.bar(x, y)
plt.title("Accuracy")

for index, value in enumerate(y):

  plt.text(value-1, index+1.2, str(value))
plt.show()
